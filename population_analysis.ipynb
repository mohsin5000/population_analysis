# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read csv
df = pd.read_csv('population.csv')
df
# Out:
#   Domain Code             Domain  Element Code           Element  Item Code  \
# 0          OA  Annual population           551  Rural population       3010
# 1          OA  Annual population           561  Urban population       3010
# 2          OA  Annual population           551  Rural population       3010
# 3          OA  Annual population           561  Urban population       3010
# 4          OA  Annual population           551  Rural population       3010
# 5          OA  Annual population           561  Urban population       3010
#
#                         Item  Year Code  Year          Unit      Value Flag  \
# 0  Population - Est. & Proj.       2018  2018  1000 persons  127183.39    A
# 1  Population - Est. & Proj.       2018  2018  1000 persons   73630.43    A
# 2  Population - Est. & Proj.       2018  2018  1000 persons  893272.09    A
# 3  Population - Est. & Proj.       2018  2018  1000 persons  460779.76    A
# ...

# %%
sns.catplot(x='Countries', y='Value', hue='Element', kind= 'bar', data=df)
plt.title("Rural and Urban Population")
plt.show()
